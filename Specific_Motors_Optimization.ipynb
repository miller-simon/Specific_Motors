# %%
import docplex.mp.model as cpx

# %%
# Part A

# Define Model
mdl_a = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_a.integer_var(name = "ft")
x2 = mdl_a.integer_var(name = "cc", ub = 3500)

#Define Constraints
mdl_a.add_constraint(6*x1 + 10.5*x2 <= 48000, ctname = "Labor Hours")
mdl_a.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_a.maximize(3600*x1 + 5400*x2)

#solving the model
s = mdl_a.solve()
print(mdl_a.export_as_lp_string())
print(s)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 3500
#
# Generals
#  ft cc
# End
#
# solution for: SM Profit Maximization
# objective: 2.664e+07
# ft=3800
# cc=2400

# %%
# Part B

# Define Model
mdl_b = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_b.integer_var(name = "ft")
x2 = mdl_b.integer_var(name = "cc", ub = 3500*1.2)

#Define Constraints
mdl_b.add_constraint(6*x1 + 10.5*x2 <= 48000, ctname = "Labor Hours")
mdl_b.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_b.maximize(3600*x1 + 5400*x2 - 500000)

#solving the model
s = mdl_b.solve()
print(mdl_b.export_as_lp_string())
print(s)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc -500000
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 4200
#
# Generals
#  ft cc
# End
#
# solution for: SM Profit Maximization
# objective: 2.614e+07
# ft=3800
# cc=2400

# %%
# Part C

# Define Model
mdl_c = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_c.integer_var(name = "ft")
x2 = mdl_c.integer_var(name = "cc", ub = 3500)
x3 = mdl_c.integer_var(name = "ot", ub = 12000 )

#Define Constraints
mdl_c.add_constraint(6*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_c.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_c.maximize(3600*x1 + 5400*x2)

#solving the model
s = mdl_c.solve()
print(mdl_c.export_as_lp_string())
print(s)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 3500
#        ot <= 12000
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 3.06e+07
# ft=3250
# cc=3500
# ot=12000

# %%
# Part D
# Answer should be difference in profit generated with new condition and old condition
# # Define Model
# mdl_d = cpx.Model("SM Profit Maximization")

# #Define Varaibles
# x1 = mdl_d.integer_var(name = "ft")
# x2 = mdl_d.integer_var(name = "cc", ub = 3500)
# x3 = mdl_d.integer_var(name = "ot", ub = 12000 )
# x4 = mdl_d.integer_var(name = "price_ot")

# #Define Constraints
# mdl_d.add_constraint(6*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
# mdl_d.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")
# mdl_d.add_constraint(3600*x1 + 5400*x2 - x3*x4 >= 2.664e+07 , ctname = "Breakeven")

# #Define Objective
# mdl_d.minimize(x4)

# #solving the model
# s = mdl_d.solve()
# print(mdl_d.export_as_lp_string())
# print(s)
# Out:
# Error: Model is non-convex
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Minimize
#  obj: price_ot
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#  Breakeven: [ - ot*price_ot ] + 3600 ft + 5400 cc >= 26640000
#
# Bounds
#        cc <= 3500
#        ot <= 12000
#
# Generals
#  ft cc ot price_ot
# End
#
# None

# %%
# Part E

#With Ads, With OT
# Define Model
mdl_e = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_e.integer_var(name = "ft")
x2 = mdl_e.integer_var(name = "cc", ub = 3500*1.2)
x3 = mdl_e.integer_var(name = "ot", ub = 12000 )

#Define Constraints
mdl_e.add_constraint(6*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_e.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_e.maximize(3600*x1 + 5400*x2 - 500000)

#solving the model
s = mdl_e.solve()
print(mdl_e.export_as_lp_string())
print(s)

########################################################################################################################

#Without Ads, With OT
# Define Model
mdl_e = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_e.integer_var(name = "ft")
x2 = mdl_e.integer_var(name = "cc", ub = 3500)
x3 = mdl_e.integer_var(name = "ot", ub = 12000 )

#Define Constraints
mdl_e.add_constraint(6*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_e.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_e.maximize(3600*x1 + 5400*x2)

#solving the model
s = mdl_e.solve()
print(mdl_e.export_as_lp_string())
print(s)

########################################################################################################################

#With Ads, Without OT
# Define Model
mdl_e = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_e.integer_var(name = "ft")
x2 = mdl_e.integer_var(name = "cc", ub = 3500*1.2)
x3 = mdl_e.integer_var(name = "ot", ub = 0 )

#Define Constraints
mdl_e.add_constraint(6*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_e.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_e.maximize(3600*x1 + 5400*x2 - 500000)

#solving the model
s = mdl_e.solve()
print(mdl_e.export_as_lp_string())
print(s)

########################################################################################################################

#Without Ads, Without OT
# Define Model
mdl_e = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_e.integer_var(name = "ft")
x2 = mdl_e.integer_var(name = "cc", ub = 3500)
x3 = mdl_e.integer_var(name = "ot", ub = 0 )

#Define Constraints
mdl_e.add_constraint(6*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_e.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_e.maximize(3600*x1 + 5400*x2)

#solving the model
s = mdl_e.solve()
print(mdl_e.export_as_lp_string())
print(s)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc -500000
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 4200
#        ot <= 12000
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 3.19e+07
# ft=3000
# cc=4000
# ot=12000
#
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 3500
#        ot <= 12000
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 3.06e+07
# ft=3250
# cc=3500
# ot=12000
#
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc -500000
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 4200
#        ot <= 0
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 2.614e+07
# ft=3800
# cc=2400
#
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 3500
#        ot <= 0
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 2.664e+07
# ft=3800
# cc=2400

# %%
# Part F

#With Ads, With OT
# Define Model
mdl_f = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_f.integer_var(name = "ft")
x2 = mdl_f.integer_var(name = "cc", ub = 3500*1.2)
x3 = mdl_f.integer_var(name = "ot", ub = 12000 )
ot_price = 1600000/12000

#Define Constraints
mdl_f.add_constraint(6*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_f.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_f.maximize(3600*x1 + 5400*x2 - ot_price*x3 -500000)

#solving the model
s = mdl_f.solve()
print(mdl_f.export_as_lp_string())
print(s)

########################################################################################################################

#Without Ads, With OT
# Define Model
mdl_f = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_f.integer_var(name = "ft")
x2 = mdl_f.integer_var(name = "cc", ub = 3500)
x3 = mdl_f.integer_var(name = "ot", ub = 12000 )
ot_price = 1600000/12000

#Define Constraints
mdl_f.add_constraint(6*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_f.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_f.maximize(3600*x1 + 5400*x2 - ot_price*x3)

#solving the model
s = mdl_f.solve()
print(mdl_f.export_as_lp_string())
print(s)

########################################################################################################################

#With Ads, Without OT
# Define Model
mdl_f = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_f.integer_var(name = "ft")
x2 = mdl_f.integer_var(name = "cc", ub = 3500*1.2)
x3 = mdl_f.integer_var(name = "ot", ub = 0 )
ot_price = 1600000/12000

#Define Constraints
mdl_f.add_constraint(6*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_f.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_f.maximize(3600*x1 + 5400*x2 - ot_price*x3 -500000)

#solving the model
s = mdl_f.solve()
print(mdl_f.export_as_lp_string())
print(s)

########################################################################################################################

#Without Ads, Without OT
# Define Model
mdl_f = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_f.integer_var(name = "ft")
x2 = mdl_f.integer_var(name = "cc", ub = 3500)
x3 = mdl_f.integer_var(name = "ot", ub = 0)
ot_price = 1600000/12000

#Define Constraints
mdl_f.add_constraint(6*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_f.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_f.maximize(3600*x1 + 5400*x2)

#solving the model
s = mdl_f.solve()
print(mdl_f.export_as_lp_string())
print(s)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc - 133.333333333333 ot -500000
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 4200
#        ot <= 12000
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 3.03e+07
# ft=3000
# cc=4000
# ot=12000
#
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc - 133.333333333333 ot
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 3500
#        ot <= 12000
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 2.95e+07
# ft=3250
# cc=3500
# ot=8250
#
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc - 133.333333333333 ot -500000
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 4200
#        ot <= 0
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 2.614e+07
# ft=3800
# cc=2400
#
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 3500
#        ot <= 0
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 2.664e+07
# ft=3800
# cc=2400

# %%
# Part G

# Define Model
mdl_g = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_g.integer_var(name = "ft")
x2 = mdl_g.integer_var(name = "cc", ub = 3500)

#Define Constraints
mdl_g.add_constraint(6*x1 + 10.5*x2 <= 48000, ctname = "Labor Hours")
mdl_g.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_g.maximize(2800*x1 + 5400*x2)

#solving the model
s = mdl_g.solve()
print(mdl_g.export_as_lp_string())
print(s)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 2800 ft + 5400 cc
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 3500
#
# Generals
#  ft cc
# End
#
# solution for: SM Profit Maximization
# objective: 2.415e+07
# ft=1875
# cc=3500

# %%
# Part H

# Define Model
mdl_h = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_h.integer_var(name = "ft")
x2 = mdl_h.integer_var(name = "cc", ub = 3500)

#Define Constraints
mdl_h.add_constraint(7.5*x1 + 10.5*x2 <= 48000, ctname = "Labor Hours")
mdl_h.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_h.maximize(3600*x1 + 5400*x2)

#solving the model
s = mdl_h.solve()
print(mdl_h.export_as_lp_string())
print(s)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc
# Subject To
#  Labor_Hours: 7.500000000000 ft + 10.500000000000 cc <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 3500
#
# Generals
#  ft cc
# End
#
# solution for: SM Profit Maximization
# objective: 2.43e+07
# ft=1500
# cc=3500

# %%
# Part I

# Define Model
mdl_i = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_i.integer_var(name = "ft")
x2 = mdl_i.integer_var(name = "cc", ub = 3500)

#Define Constraints
mdl_i.add_constraint(6*x1 + 10.5*x2 <= 48000, ctname = "Labor Hours")
mdl_i.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")
mdl_i.add_constraint(x2 == 3500)

#Define Objective
mdl_i.maximize(3600*x1 + 5400*x2)

#solving the model
s = mdl_i.solve()
print(mdl_i.export_as_lp_string())
print(s)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 3600 ft + 5400 cc
# Subject To
#  Labor_Hours: 6 ft + 10.500000000000 cc <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#  c3: cc = 3500
#
# Bounds
#        cc <= 3500
#
# Generals
#  ft cc
# End
#
# solution for: SM Profit Maximization
# objective: 2.565e+07
# ft=1875
# cc=3500

# %%
# Part J

#With Ads, With OT
# Define Model
mdl_j = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_j.integer_var(name = "ft")
x2 = mdl_j.integer_var(name = "cc", ub = 3500*1.2)
x3 = mdl_j.integer_var(name = "ot", ub = 12000 )
ot_price = 1600000/12000

#Define Constraints
mdl_j.add_constraint(7.5*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_j.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_j.maximize(2800*x1 + 5400*x2 - ot_price*x3 -500000)

#solving the model
s = mdl_j.solve()
print(mdl_j.export_as_lp_string())
print(s)

########################################################################################################################

#Without Ads, With OT
# Define Model
mdl_j = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_j.integer_var(name = "ft")
x2 = mdl_j.integer_var(name = "cc", ub = 3500)
x3 = mdl_j.integer_var(name = "ot", ub = 12000 )
ot_price = 1600000/12000

#Define Constraints
mdl_j.add_constraint(7.5*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_j.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_j.maximize(2800*x1 + 5400*x2 - ot_price*x3)

#solving the model
s = mdl_j.solve()
print(mdl_j.export_as_lp_string())
print(s)

########################################################################################################################

#With Ads, Without OT
# Define Model
mdl_j = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_j.integer_var(name = "ft")
x2 = mdl_j.integer_var(name = "cc", ub = 3500*1.2)
x3 = mdl_j.integer_var(name = "ot", ub = 0 )
ot_price = 1600000/12000

#Define Constraints
mdl_j.add_constraint(7.5*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_j.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_j.maximize(2800*x1 + 5400*x2 - ot_price*x3 -500000)

#solving the model
s = mdl_j.solve()
print(mdl_j.export_as_lp_string())
print(s)

########################################################################################################################

#Without Ads, Without OT
# Define Model
mdl_j = cpx.Model("SM Profit Maximization")

#Define Varaibles
x1 = mdl_j.integer_var(name = "ft")
x2 = mdl_j.integer_var(name = "cc", ub = 3500)
x3 = mdl_j.integer_var(name = "ot", ub = 0)
ot_price = 1600000/12000

#Define Constraints
mdl_j.add_constraint(7.5*x1 + 10.5*x2 <= 48000 + x3, ctname = "Labor Hours")
mdl_j.add_constraint(4*x1 + 2*x2 <= 20000, ctname = "Doors")

#Define Objective
mdl_j.maximize(2800*x1 + 5400*x2)

#solving the model
s = mdl_j.solve()
print(mdl_j.export_as_lp_string())
print(s)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 2800 ft + 5400 cc - 133.333333333333 ot -500000
# Subject To
#  Labor_Hours: 7.500000000000 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 4200
#        ot <= 12000
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 2.6516e+07
# ft=2120
# cc=4200
# ot=12000
#
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 2800 ft + 5400 cc - 133.333333333333 ot
# Subject To
#  Labor_Hours: 7.500000000000 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 3500
#        ot <= 12000
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 2.598e+07
# ft=3100
# cc=3500
# ot=12000
#
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 2800 ft + 5400 cc - 133.333333333333 ot -500000
# Subject To
#  Labor_Hours: 7.500000000000 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 4200
#        ot <= 0
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 2.3636e+07
# ft=520
# cc=4200
#
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: SM Profit Maximization
#
# Maximize
#  obj: 2800 ft + 5400 cc
# Subject To
#  Labor_Hours: 7.500000000000 ft + 10.500000000000 cc - ot <= 48000
#  Doors: 4 ft + 2 cc <= 20000
#
# Bounds
#        cc <= 3500
#        ot <= 0
#
# Generals
#  ft cc ot
# End
#
# solution for: SM Profit Maximization
# objective: 2.31e+07
# ft=1500
# cc=3500
